# %% [markdown]
# **Python print function,string and variable -**
#
#
# *  print() function: This function is used to print any statement or variable on to the screen. If we pass on any object to the print() function it will be first converted to string and then displayed on the screen as a string.
#
# ```
# print("1. Hey, Welcome to Python")
# print('I can print like this as well')
# o/p: 1. Hey, Welcome to Python
#         I can print like this as well
# ```
# ```
# a = 5
# print("2. Printing a variable:",a)
# o/p: 2. Printing a variable: 5
# ```
# ```
# st = "hey"
# print("3. Printing more than one object: ",st,"how are you?")
# print("Bella","Ciao")
# print(5,3)
# o/p: 3. Printing more than one object:  hey how are you?
#         Bella Ciao
#         5 3
# ```
# ```
# x = 10
# y = -20
# print("4. Printing the sum of two variables: ",x+y)
# print("Printing the product of two variables: ",x*y)
# o/p: 4. Printing the sum of two variables:  -10
#         Printing the product of two variables:  -200
# ```
# ```
# tup = ("This","is","a","tuple")
# print("5. Printing a tuple:",tup)
# o/p: 5. Printing a tuple: ('This', 'is', 'a', 'tuple')
# ```
# ```
# print("6. Printing two objects with a separator other than space:")
# print("My "," Precious",sep="*_*")
# o/p: 6. Printing two objects with a separator other than space:
#         My *_* Precious
# ```
# ```
# print("7. Printing two statements on the same line:")
# print("Is it the same",end=" ")
# print("line?")
# o/p: 7. Printing two statements on the same line:
#         Is it the same line?
# ```
# ```
# print("8. Printing on the", end="\n\n")
# print("next to next line")
# o/p: 8. Printing on the
#
#         next to next line
# ```
# ```
# print("9. Printing with double quotes,can be done using escape character:""He said, \"Hello there!\" ")
# o/p: 9. Printing with double quotes,can be done using escape character:He said, "Hello there!"
# ```
# ```
# print("10. Printing two strings by concatenating them:"+"See,"+"I told you")
# o/p: 10. Printing two strings by concatenating them:See,I told you
#
# ```
# ```
# print("11. Some of the ways to print:")
# print(13,"B"+"Baker Street")
# print("13B","Baker Street")
# print(str(13)+"B","Baker Street")
# o/p: 11. Some of the ways to print:
#         13 BBaker Street
#         13B Baker Street
#         13B Baker Street
# ```
# *****************************************************
# *  strings: Strings are basically arrays of characters in python. These are denoted by single quotes ' ' or double quotes " "Strings are immutable and hence cannot be changed.
#
# ```
# String_1 = "String can be printed like this"
# String_2 = 'or like this'
# print("13. ",String_1)
# print(String_2)
# o/p: 13.  String can be printed like this
#           or like this
# ```
# ```
# print("""14. Multi-line
# strings
# printed together""")
# print('''Well, you can do it
# this was as well''')
# o/p: 14. Multi-line
#         strings
#         printed together
#         Well, you can do it
#         this was as well
#
# ```
# ****************************************************
# *  variables: Variables store values when they are assigned. They do no need to be declared in python and does not require to be of any particular type. Variables can change by re-assigning them.
# ```
# print("23. Variables can be re-assigned to any data type")
# x = 12.45
# print("x has floating value:",x)
# x = 87
# print("x has integer value:",x)
# x = "Salvadore"
# print("x has string:",x)
# o/p: 23. Variables can be re-assigned to any data type
# x has floating value: 12.45
# x has integer value: 87
# x has string: Salvadore
# ```
# ```
# print("24. Naming a variable:")
# print("Variable name should start with a letter or underscore and no numbers")
# var = 10
# _var = 20
# print("No special character allowed except for underscore other than alphanumeric characters")
# V_ar = 70
# VAR = 90
# Var = 100
# print("Variables in python are case-sensitive: var = ",var,"and Var = ",Var,"are different")
# print("""Not allowed: 32var = 30
# 3_2var = 40
# va*r = 50
# v'ar = 60
# var-var = 80 """)
# o/p: 24. Naming a variable:
# Variable name should start with a letter or underscore and no numbers
# No special character allowed except for underscore other than alphanumeric characters
# Variables in python are case-sensitive: var =  10 and Var =  100 are different
# Not allowed: 32var = 30
# 3_2var = 40
# va*r = 50
# v'ar = 60
# var-var = 80
# ```
# ```
# print("25. assigning more than one variable together")
# x,y,z = 10,20,30
# print("x=",x)
# print("y=",y)
# print("z=",z)
# o/p: 25. assigning more than one variable together
# x= 10
# y= 20
# z= 30
#
# ```
# w = "Life's "
# x = 2
# y = 5
# z = "Good!"
# print("26. Variables storing strings can be concatenated using + :",w+z)
# print("Variables storing integers are added using + :",x+y)
# o/p: 26. Variables storing strings can be concatenated using + : Life's Good!
# Variables storing integers are added using + : 7
# ```
# ```
# x = 5
# print("27. Global variable before using function x = ",x)
# def myfunct():
#   x = 100
#   x = x + 10
#   print("Local variable x = ",x)
# myfunct()
# print("Global variable after using function x = ",x)
# print("Variables used outside a function can be used gloablly and hence are called global variables and those used in the function are called local variables.")
# o/p: 27. Global variable before using function x =  5
# Local variable x =  110
# Global variable after using function x =  5
# Variables used outside a function can be used gloablly and hence are called global variables and those used in the function are called local variables.
#
# ```

# %% [markdown]
# **Operations and Built-in functions**-
# *   Operations: Operators are used to perform certain functions on objects in
# python which includes the variables and values.
#
# ```
# print("1. Assignment operations:")
# a = 10
# print("Assign value: a = 10 => value stored by a =",a)
# a += 5
# print("Add and assign value '+':",a)
# a -= 5
# print("Subtract and assign value '-':",a)
# a *= 5
# print("Multiply and assign value '*':",a)
# a /= 5
# print("Divide and assign value '/':",a)
# a %= 5
# print("Find modulus and assign value '%':",a)
# a**=5
# print("Find exponential and assign value '**':",a)
# a//=5
# print("Floor division and assign value '//':",a)
# o/p: 1. Assignment operations:
# Assign value: a = 10 => value stored by a = 10
# Add and assign value '+': 15
# Subtract and assign value '-': 10
# Multiply and assign value '*': 50
# Divide and assign value '/': 10.0
# Find modulus and assign value '%': 0.0
# Find exponential and assign value '**': 0.0
# Floor division and assign value '//': 0.0
# ```
# ```
# x = 20.6
# y = 18
# print("2. Arithmetic functions include:")
# print("Addition '+':",x+y)
# print("Subtraction '-':",x-y)
# print("Multiplication '*':",x*y)
# print("Division '/':",x/y)
# print("Modulus '%':",x%y)
# print("Exponential '**':",x**y)
# print("Floor division '//':",x//y)
# o/p: 2. Arithmetic functions include:
# Addition '+': 38.6
# Subtraction '-': 2.6000000000000014
# Multiplication '*': 370.8
# Division '/': 1.1444444444444446
# Modulus '%': 2.6000000000000014
# Exponential '**': 4.4628261240567386e+23
# Floor division '//': 1.0
# ```
# ```
# print("3. Relational Operators:")
# b = 100
# c = 200
# print("equal then true '==':",b==c)
# print("not equal then true '!=':",b!=c)
# print("less then true '<':",b<c)
# print("greater then true '>':",b>c)
# print("less or equal then true '<=':",b<=c)
# print("greater or equal then true '>=':",b>=c)
# o/p: 3. Relational Operators:
# equal then true '==': False
# not equal then true '!=': True
# less then true '<': True
# greater then true '>': False
# less or equal then true '<=': True
# greater or equal then true '>=': False
# ```
# ```
# today = 'Monday'
# tomorrow = 'Tuesday'
# print("4. True if both statements are true:",today == 'Monday' and tomorrow == 'Tuesday')
# print("True if both statements if even dither one of them is true:",today == 'Monday' or tomorrow == 'Thursday')
# print("Reverses the result and returns true if result is false:",not(today == 'Monday' and tomorrow == 'Thursday'))
# o/p: 4. True if both statements are true: True
# True if both statements if even dither one of them is true: True
# Reverses the result and returns true if result is false: True
# ```
# *****************************************************
# *   Built-in functions: These are functions which are already built-in into Python and can be accessed directly by the users whenever required.
#
#
# ```
# print("5. Some of the built-in functions in Python include:")
# print("This is a built-in function!")
# x = abs(-5/3)
# print("abs(-5/3)= ",x)
# x = round(-5/3)
# print("round(-5/3 = ",x)
# lst = (3,2,1,4)
# print("Get minimum value, min(lst):",min(lst))
# print("Get maximum value, max(lst):",max(lst))
# print("Get sorted list, sorted(lst):",sorted(lst))
# print("Get sum of all the values, sum(lst):",sum(lst))
# print("Get length, len(lst):",len(lst))
# val_1 = 23.567
# val_2 = False
# val_3 = -45
# print("Get type of the value, type(val_1):",type(val_1))
# print("type(val_2):",type(val_2))
# print("type(val_3):",type(val_3))
# String_ = " HEy,Soul siSTer"
# print(String_.lower())
# print(String_.upper())
# print(String_.replace('s','w'))
# print(String_.split(','))
# print("Removes extra blank spaces",String_.strip())
# o/p: 5. Some of the built-in functions in Python include:
# This is a built-in function!
# abs(-5/3)=  1.6666666666666667
# round(-5/3 =  -2
# Get minimum value, min(lst): 1
# Get maximum value, max(lst): 4
# Get sorted list, sorted(lst): [1, 2, 3, 4]
# Get sum of all the values, sum(lst): 10
# Get length, len(lst): 4
# Get type of the value, type(val_1): <class 'float'>
# type(val_2): <class 'bool'>
# type(val_3): <class 'int'>
#  hey,soul sister
#  HEY,SOUL SISTER
#  HEy,Soul wiSTer
# [' HEy', 'Soul siSTer']
# Removes extra blank spaces HEy,Soul siSTer
# ```

# %% [markdown]
# **Lists,sets,tuples,dictionaries-**
# These are built-in data structures in python.
#
# *  *lists*: Stores a list of values which are indexed. Lists are mutable and ordered (have sequence).They are accessed via indexing.
# *  *tuples*: tuples are faster than lists. These are ordered but not mutable.
# *   *sets*: Sets are unordered and mutable. These cannot have duplicate values.
# *   *dictionary*: Dictionaries store values as key-value pair. These are mutable and unordered. Here the values can be repeated but not the keys.Dictionaries are accessed via keys.
# Both list and dictionary can be nested.
# ```
# print("1. List are created using []")
# list_ = []
# print("Create empty list",list_)
# lst = [1,-5,'yolo',78.09]
# print("List is created and initialised:",lst)
# o/p: 1. List are created using []
# Create empty list []
# List is created and initialised: [1, -5, 'yolo', 78.09]
# ```
# ```
# tup = (2,'lit',23.65)
# print("2. Tuple is created:",tup)
# tup_ = (tup)
# print("create tuple using tuple",tup_)
# tup_ = (lst)
# print("Create tuple using list",tup_)
# tup_ = tuple('HERE')
# print("Creating tuple of string using built-in function",tup_)
# tup_1 = (tup,tup_)
# print("Nested tuple",tup_1)
# tup_2 = ('ooh',) * 3
# print("Tuples with repetition:",tup_2)
# print("Access any value of tuple:",tup[2])
# a,b,c = tup_2
# print("assigning variables to values in tuple: a =",a,"b =",b,"c =",c)
# tup_3 = tup_1 + tup_2
# print("Tuples concatenated:",tup_3)
# print("slicing of tuples:",tup_3[2:5])
# print("tuples can be deleted: del(tuple_name)")
# o/p: 2. Tuple is created: (2, 'lit', 23.65)
# create tuple using tuple (2, 'lit', 23.65)
# Create tuple using list [1, -5, 'yolo', 78.09]
# Creating tuple of string using built-in function ('H', 'E', 'R', 'E')
# Nested tuple ((2, 'lit', 23.65), ('H', 'E', 'R', 'E'))
# Tuples with repetition: ('ooh', 'ooh', 'ooh')
# Access any value of tuple: 23.65
# assigning variables to values in tuple: a = ooh b = ooh c = ooh
# Tuples concatenated: ((2, 'lit', 23.65), ('H', 'E', 'R', 'E'), 'ooh', 'ooh', 'ooh')
# slicing of tuples: ('ooh', 'ooh', 'ooh')
# tuples can be deleted: del(tuple_name)
#
# ```
# set_ = {'a',1,5,3,7,9,'hey'}
# print("3. Set is created:",set_)
# set_1 = set('We will rock you')
# print("Creating set using string with built-in function",set_1)
# set_2 = set(lst)
# print("Creating set using list",set_2)
# set_2.add(56)
# set_2.add((5,6))
# print("Add value and tuple to set",set_2)
# set_2.update(['new','value'])
# print("Adding more than 1 value in set at a time",set_2)
# check = "value" in set_2
# print("check if a value is present in the set:",check)
# print("Access set using loops:")
# for i in set_:
#   if(i == 'hey'):
#     print(i)
# print("# If an element is already removed from set,remove() will givw an error whereas discard() won't")
# set_.remove('a')
# print("Remove from set",set_)
# set_.discard('a')
# print("Discard from set",set_)
# set_1.pop()
# print("Pop element from set",set_1)
# set_1.clear()
# print("Clear the set:",set_1)
# set_3 = frozenset('We will rock you')
# print("Frozensets are immutable sets & cannot be changed",set_3)
# o/p: 3. Set is created: {1, 3, 5, 7, 'hey', 9, 'a'}
# Creating set using string with built-in function {' ', 'l', 'c', 'y', 'u', 'i', 'e', 'W', 'w', 'o', 'k', 'r'}
# Creating set using list {1, -5, 'yolo', 78.09}
# Add value and tuple to set {1, (5, 6), 'yolo', 78.09, 56, -5}
# Adding more than 1 value in set at a time {1, 'value', (5, 6), 'yolo', 78.09, 'new', 56, -5}
# check if a value is present in the set: True
# Access set using loops:
# hey
# # If an element is already removed from set,remove() will givw an error whereas discard() won't
# Remove from set {1, 3, 5, 7, 'hey', 9}
# Discard from set {1, 3, 5, 7, 'hey', 9}
# Pop element from set {'l', 'c', 'y', 'u', 'i', 'e', 'W', 'w', 'o', 'k', 'r'}
# Clear the set: set()
# Frozensets are immutable sets & cannot be changed frozenset({' ', 'l', 'c', 'y', 'u', 'i', 'e', 'W', 'w', 'o', 'k', 'r'})
# ```
# ```
# dict_ = {'name':'Mikesh','age':34,'job':'Data analyst'}
# print("4. Dictionary is created:",dict_)
# dict_1 = {1: 'Father', 2: 'Mother', 3:{'A' : 'Son', 'B' : 'Daughter'}}
# print("Nested dictionary",dict_1)
# dict_2={}
# dict_2[1] = 1
# dict_2['pet'] = 'Dog'
# dict_2['types'] = 'Poodle','Husky'
# print("Adding new elements using key:",dict_2)
# print("Access the dictionary using key:",dict_2['types'])
# print("Access dictionary using get():",dict_2.get(1))
# print("Access element of a nested dictionary:",dict_1[3]['B'])
# popped = dict_.pop('age')
# print("Dictionary after pop",dict_)
# print("value of popped element:",popped)
# dict_.clear()
# print("[del() will completely delete the dictionary] Clearing dictionary:",dict_)
# o/p: 4. Dictionary is created: {'name': 'Mikesh', 'age': 34, 'job': 'Data analyst'}
# Nested dictionary {1: 'Father', 2: 'Mother', 3: {'A': 'Son', 'B': 'Daughter'}}
# Adding new elements using key: {1: 1, 'pet': 'Dog', 'types': ('Poodle', 'Husky')}
# Access the dictionary using key: ('Poodle', 'Husky')
# Access dictionary using get(): 1
# Access element of a nested dictionary: Daughter
# Dictionary after pop {'name': 'Mikesh', 'job': 'Data analyst'}
# value of popped element: 34
# [del() will completely delete the dictionary] Clearing dictionary: {}
# ```

# %% [markdown]
# **List Operations and String Manipulations**-
#
# List Operations:")
# ```
# lst = [1,-5,'yolo',78.09]
# print("Accessing a value from list:",lst[3],lst[-2])
# lst_1 = [1,-5,['hey','how are you?'],0]
# print("Append new value to list:")
# lst.append(5)
# print(lst)
# print("Append list to another list:")
# lst_1.append(lst)
# print(lst_1)
# print("Extend list by another list:")
# lst_2 = ['a','b','c']
# lst.extend(lst_2)
# print(lst)
# print("Nested list:",lst_1)
# print("Insert a value to any index of list:")
# lst.insert(0,'Good')
# print(lst)
# print("Remove value from list:")
# lst.remove(-5)
# print(lst)
# lst.pop()
# print("Pop value from list:",lst)
# print("Slice list and print:",lst_1[2:4])
# lst_1.reverse()
# print("Reverse a list:",lst_1)
# lst_1.clear()
# print("Clear list:",lst_1)
# o/p:
# Accessing a value from list: 78.09 yolo
# Append new value to list:
# [1, -5, 'yolo', 78.09, 5]
# Append list to another list:
# [1, -5, ['hey', 'how are you?'], 0, [1, -5, 'yolo', 78.09, 5]]
# Extend list by another list:
# [1, -5, 'yolo', 78.09, 5, 'a', 'b', 'c']
# Nested list: [1, -5, ['hey', 'how are you?'], 0, [1, -5, 'yolo', 78.09, 5, 'a', 'b', 'c']]
# Insert a value to any index of list:
# ['Good', 1, -5, 'yolo', 78.09, 5, 'a', 'b', 'c']
# Remove value from list:
# ['Good', 1, 'yolo', 78.09, 5, 'a', 'b', 'c']
# Pop value from list: ['Good', 1, 'yolo', 78.09, 5, 'a', 'b']
# Slice list and print: [['hey', 'how are you?'], 0]
# Reverse a list: [['Good', 1, 'yolo', 78.09, 5, 'a', 'b'], 0, ['hey', 'how are you?'], -5, 1]
# Clear list: []
# ```
# *****************************************************
# String Manipulations:
# ```
# String_ = 'strings are arrays'
# String_3 = 'Corona'
# print("1. Accessing string character: ",String_3[1], String_3[3]) #Strings are arrays and hence you can access any character of string using index
# o/p: 1. Accessing string character:  o o
#
# ```
# ```
# print("2. length = ",len(String_3)) #Get length of string:
# o/p: 2. length = 6
# ```
# ```
# print("3. Last character of the string:",String_3[-1])
# o/p: 3. Last character of the string: a
# ```
# ```
# print("4.Slicing the string:")
# print("Prints character from index-1 to index-3:",String_3[1:4])
# print("Prints 5th last to 3rd last characters:",String_3[-5:-2])
# o/p: 4.Slicing the string:
# Prints character from index-1 to index-3: oro
# Prints 5th last to 3rd last characters: oro
# ```
# ```
# String_4 = "PIVOT!"
# String_5 = 'ConFuSEd'
# print("5. Converting to lower case:",String_5.lower())
# print("Converting to upper case:",String_5.upper())
# print("Check if string is lower case:",String_5.islower())
# print("Check if string is upper case:",String_4.isupper())
# print("Toggle case:",String_5.swapcase())
# print("Capitalize the string:",String_.capitalize())
# o/p: 5. Converting to lower case: confused
# Converting to upper case: CONFUSED
# Check if string is lower case: False
# Check if string is upper case: True
# Toggle case: cONfUseD
# Capitalize the string: Strings are arrays
# ```
# ```
# String_6 = "English, is a, funny language"
# print("6. Split strings:",String_6.split(',') )
# print("Replace characters in the string:",String_6.replace('n','o'))
# o/p: 6. Split strings: ['English', ' is a', ' funny language']
# Replace characters in the string: Eoglish, is a, fuooy laoguage
# ```
# ```
# String_7 = "Ironman and Spiderman "
# not_in = 'ron' not in String_7
# print("7. Checking if a particular string is present in the given string:",not_in)
# not_in = 'man' in String_7
# print(not_in)
# o/p: 7. Checking if a particular string is present in the given string: False
# True
# ```
# ```
# age = 20
# weight = 60.6
# String_8 = "Abdul is {} years old and weighs {} kgs."
# print("8. Format strings and use wherever required:",String_8.format(age,weight))
# print("Abdul is %d years old and weighs %0.8f kgs" % (age,weight))
# o/p: 8. Format strings and use wherever required: Abdul is 20 years old and weighs 60.6 kgs.
# Abdul is 20 years old and weighs 60.60000000 kgs
# ```
#
#
# ```
# String_9 = 'Well here we go again and again...'
# print("9. count how many times 'again' is in the string:",String_9.count('again'))
# print("find the word 'again' in the string:",String_9.find('again'))
# print("find the index of 'go' in the string:",String_9.index('go'))
# o/p: 9. count how many times 'again' is in the string: 2
# find the word 'again' in the string: 16
# find the index of 'go' in the string: 13
# ```
# ```
# print('10. Reverse a string and join characters with space:',' '.join(reversed(String_9)))
# print('='.join(reversed(String_9)))
#
# String_10 = '123abc'
# print("check if all char are alphanumeric:",String_10.isalnum())
# print("check if all char in the string are alphabetic:",String_10.isalpha())
# print("test if string contains digits:",String_10.isdigit())
# print("test if string contains upper case:",String_10.isupper())
# print("test if string contains lower case:",String_10.islower())
# print("test if string contains spaces:",String_10.isspace())
# o/p: 10. Reverse a string and join characters with space: . . . n i a g a   d n a   n i a g a   o g   e w   e r e h   l l e W
# .=.=.=n=i=a=g=a= =d=n=a= =n=i=a=g=a= =o=g= =e=w= =e=r=e=h= =l=l=e=W
# check if all char are alphanumeric: True
# check if all char in the string are alphabetic: False
# test if string contains digits: False
# test if string contains upper case: False
# test if string contains lower case: True
# test if string contains spaces: False
# ```

# %% [markdown]
# **Defining functions-**
#
# We need to call a function to execute it and in order to call we first need to define the function
#
# 1.
#
# > defining a function using syntax, 'def function_name(parameter): '.Function can take any number of parameters.
#
#     def my_function():
#       print("This is a function")
#     my_function()       #calling the function
# o/p: This is a function
#
# 2.
#
# > list can be passed as arguments for the function.
#
#     def my_function(dogs):
#     for x in dogs:
#       print(x)
#     dogs = ["poodle", "husky"]
#     my_function(dogs)
#
# o/p: poodle
# husky
#
# 3.
#
# >  #function can return a value.Use keyword 'return'
#
#     def my_function(val):
#       res = val * val       #function to calculate square of a value
#       return res
#     res = my_function(4)
#     print("result = ",res)
# o/p: result =  16

# %% [markdown]
# **Importing modules-**
#
# *   modules holds a set of code or functions that we want in our application/program
# *   whenever we require the module we just need to import it into our code
#
# Consider if I want to create an application where I would have to greet the user on the opening page.
#
# > def greet_user(name):
#
#       print("Hello and welcome " + name)
#
# save this above code as 'module.py'
#
# Whenever the user enters the name,the following code will be used.
#
#
# > #importing the module we created
#
#     import module
#     module.greet_user("Mikesh")   #access the code from the module and get output from the desired function

# %% [markdown]
# **Downloading any external modue(library) using pip**-
#
#
# *   **step 1:** The first step is to ensure that python is installed in out computer
#         type 'python --version' on cmd and you'll get the version of python installed. If not installed it will show that it's not recognized
# *   **step 2:**navigate to whatever directory you’ve placed python into and install pip
#         'python get-pip.py to install pip'
# *   **step 3:**In windows you can directly install any library using pip
#         'pip install numpy'
#         'pip install sklearn'
#        In linux/mac we may need 'sudo'
#         'sudo pip install numpy'
#         'sudo pip install sklearn'
